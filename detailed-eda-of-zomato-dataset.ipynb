# %%
import pandas as pd
import matplotlib.pyplot as plt
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import seaborn as sns 
import seaborn as sns 
import plotly.express as px
pd.set_option('display.max_columns',None)
df = pd.read_csv("C:/Users/mahes/OneDrive/Desktop/data analysis python/pandas/zomato.csv", encoding='latin1')
df.head(2)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  Average Cost for two          Currency  \
# 0  French, Japanese, Desserts                  1100  Botswana Pula(P)
# 1                    Japanese                  1200  Botswana Pula(P)
#
#   Has Table booking Has Online delivery Is delivering now  \
# 0               Yes                  No                No
# 1               Yes                  No                No
#
#   Switch to order menu  Price range  Aggregate rating Rating color  \
# 0                   No            3               4.8   Dark Green
# 1                   No            3               4.5   Dark Green
#
#   Rating text  Votes
# 0   Excellent    314
# 1   Excellent    591

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\mahes\appdata\local\programs\python\python310\lib\site-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in c:\users\mahes\appdata\local\programs\python\python310\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\mahes\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\mahes\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\mahes\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\mahes\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\mahes\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\mahes\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\mahes\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\mahes\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\mahes\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\mahes\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\mahes\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\mahes\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\mahes\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\mahes\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\mahes\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\mahes\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\mahes\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\mahes\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df2=pd.read_excel(r"C:\Users\mahes\OneDrive\Desktop\data analysis python\pandas\Country-Code.xlsx")
df2
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df=pd.merge(df,df2,on='Country Code',how='left')

# %%
df.shape
# Out:
# (9551, 22)

# %%
data=df[df['Country']=='India']

# %%
index=df.Country.value_counts().index

# %%
no=df.Country.value_counts().values

# %%
plt.pie(no[:3],labels=index[:3])
# Out:
# ([<matplotlib.patches.Wedge at 0x17efe57cee0>,
#   <matplotlib.patches.Wedge at 0x17efe57d240>,
#   <matplotlib.patches.Wedge at 0x17efe57d6c0>],
#  [Text(-1.0829742700952103, 0.19278674827836725, 'India'),
#   Text(1.077281715838356, -0.22240527134123297, 'United States'),
#   Text(1.0995865153823035, -0.03015783794312073, 'United Kingdom')])

# %% [markdown]
# As we ca see from the above pie chart that india dominate the food market in zomato

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
ratings=df.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:"Rating Count"})

# %%
# displaying diff types of ratings 
sns.barplot(x='Aggregate rating',y='Rating Count',hue='Rating color',data=ratings,palette=['blue','red','green','yellow','pink','orange'])
# Out:
# <AxesSubplot: xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
sns.countplot(x='Rating color',data=ratings)
# Out:
# <AxesSubplot: xlabel='Rating color', ylabel='count'>

# %% [markdown]
# Which country Give 0 rating

# %%
df.groupby(['Aggregate rating','Country']).size().reset_index().sort_values(by='Aggregate rating',ascending=True).head(10)
# Out:
#    Aggregate rating         Country     0
# 0               0.0          Brazil     5
# 1               0.0           India  2139
# 2               0.0  United Kingdom     1
# 3               0.0   United States     3
# 4               1.8           India     1
# 5               1.9           India     2
# 6               2.0           India     7
# 7               2.1           India    15
# 8               2.2           India    26
# 9               2.2   United States     1

# %% [markdown]
# Which Country Give GOOD Rating

# %%
# good ratings 
df[df['Rating color']=='Green'].groupby('Country').size().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='Country'>

# %% [markdown]
# Country with No Rating

# %%
# no rating
df[df['Rating color']=='White'].groupby('Country').size().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='Country'>

# %% [markdown]
# Country which Gave Poor Rating

# %%
# poor  ratings
df[df['Rating color']=='Red'].groupby('Country').size().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='Country'>

# %% [markdown]
# Country with Excellent Ratings

# %%
# excellent rating 
df[df['Rating color']=='Dark Green'].groupby('Country').size().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='Country'>

# %% [markdown]
# Top 20 Cuisines

# %%
df.Cuisines.value_counts().head(20).plot(kind='bar')
# Out:
# <AxesSubplot: >

# %% [markdown]
# As You Can Notice That India is Dominant in this dataset so i will do some analysis only on india after filtering the dataset

# %%
# data=df[df['Country']=='India']
data.head()
# Out:
#      Restaurant ID                        Restaurant Name  Country Code  City  \
# 624        3400025                             Jahanpanah             1  Agra
# 625        3400341                    Rangrezz Restaurant             1  Agra
# 626        3400005                Time2Eat - Mama Chicken             1  Agra
# 627        3400021  Chokho Jeeman Marwari Jain Bhojanalya             1  Agra
# 628        3400017                         Pinch Of Spice             1  Agra
#
#                                                Address     Locality  \
# 624  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 625  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 626        Main Market, Sadar Bazaar, Agra Cantt, Agra   Agra Cantt
# 627  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...  Civil Lines
# 628  23/453, Opposite Sanjay Cinema, Wazipura Road,...  Civil Lines
#
#       Locality Verbose  Longitude   Latitude                        Cuisines  \
# 624   Agra Cantt, Agra  78.011544  27.161661           North Indian, Mughlai
# 625   Agra Cantt, Agra   0.000000   0.000000           North Indian, Mughlai
# 626   Agra Cantt, Agra  78.011608  27.160832                    North Indian
# 627  Civil Lines, Agra  77.998092  27.195928                      Rajasthani
# 628  Civil Lines, Agra  78.007553  27.201725  North Indian, Chinese, Mughlai
#
#      Average Cost for two            Currency Has Table booking  \
# 624                   850  Indian Rupees(Rs.)                No
# 625                   700  Indian Rupees(Rs.)                No
# 626                   500  Indian Rupees(Rs.)                No
# 627                   400  Indian Rupees(Rs.)                No
# 628                  1000  Indian Rupees(Rs.)                No
#
#     Has Online delivery Is delivering now Switch to order menu  Price range  \
# 624                  No                No                   No            3
# 625                  No                No                   No            2
# 626                  No                No                   No            2
# 627                  No                No                   No            2
# 628                  No                No                   No            3
#
#      Aggregate rating Rating color Rating text  Votes Country
# 624               3.9       Yellow        Good    140   India
# 625               3.5       Yellow        Good     71   India
# 626               3.6       Yellow        Good     94   India
# 627               4.0        Green   Very Good     87   India
# 628               4.2        Green   Very Good    177   India

# %%
data.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['City'].unique()
# Out:
# array(['Agra', 'Ahmedabad', 'Allahabad', 'Amritsar', 'Aurangabad',
#        'Bangalore', 'Bhopal', 'Bhubaneshwar', 'Chandigarh', 'Chennai',
#        'Coimbatore', 'Dehradun', 'Faridabad', 'Ghaziabad', 'Goa',
#        'Gurgaon', 'Guwahati', 'Hyderabad', 'Indore', 'Jaipur', 'Kanpur',
#        'Kochi', 'Kolkata', 'Lucknow', 'Ludhiana', 'Mangalore', 'Mohali',
#        'Mumbai', 'Mysore', 'Nagpur', 'Nashik', 'New Delhi', 'Noida',
#        'Panchkula', 'Patna', 'Puducherry', 'Pune', 'Ranchi',
#        'Secunderabad', 'Surat', 'Vadodara', 'Varanasi', 'Vizag'],
#       dtype=object)

# %% [markdown]
# Some cuisines that are popular in india

# %%
data['Cuisines'].value_counts().sort_values(ascending=False).head(30).plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
data['Restaurant Name'].unique().shape
# Out:
# (6604,)

# %%
data.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index()
# Out:
#     Aggregate rating Rating color Rating text     0
# 0                0.0        White   Not rated  2139
# 1                1.8          Red        Poor     1
# 2                1.9          Red        Poor     2
# 3                2.0          Red        Poor     7
# 4                2.1          Red        Poor    15
# 5                2.2          Red        Poor    26
# 6                2.3          Red        Poor    46
# 7                2.4          Red        Poor    83
# 8                2.5       Orange     Average   109
# 9                2.6       Orange     Average   190
# 10               2.7       Orange     Average   250
# 11               2.8       Orange     Average   314
# 12               2.9       Orange     Average   380
# 13               3.0       Orange     Average   465
# 14               3.1       Orange     Average   511
# 15               3.2       Orange     Average   510
# 16               3.3       Orange     Average   472
# 17               3.4       Orange     Average   477
# 18               3.5       Yellow        Good   454
# 19               3.6       Yellow        Good   411
# 20               3.7       Yellow        Good   363
# 21               3.8       Yellow        Good   336
# 22               3.9       Yellow        Good   283
# 23               4.0        Green   Very Good   193
# 24               4.1        Green   Very Good   185
# 25               4.2        Green   Very Good   140
# 26               4.3        Green   Very Good   100
# 27               4.4        Green   Very Good    74
# 28               4.5   Dark Green   Excellent    37
# 29               4.6   Dark Green   Excellent    35
# 30               4.7   Dark Green   Excellent    16
# 31               4.8   Dark Green   Excellent     9
# 32               4.9   Dark Green   Excellent    19

# %%
costly=data[data['Average Cost for two']>3000].drop_duplicates()

# %% [markdown]
# The bar graph shows that New Delhi has many costly restraunts max Price is 8000 for two persons

# %%
fig=px.bar(costly,x='City',y='Average Cost for two')
fig.show()
# Out:
# <div>                            <div id="ad2cebce-1c89-4d4e-85eb-d8daa6272687" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad2cebce-1c89-4d4e-85eb-d8daa6272687")) {                    Plotly.newPlot(                        "ad2cebce-1c89-4d4e-85eb-d8daa6272687",                        [{"alignmentgroup":"True","hovertemplate":"City=%{x}\u003cbr\u003eAverage Cost for two=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Agra","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","Noida","Noida"],"xaxis":"x","y":[3600,3500,5000,3200,4500,4000,3300,3500,4000,5000,3500,4000,3650,4800,4000,3300,4000,3500,4500,4000,4500,3500,6500,7000,5000,3500,4500,5000,4500,4500,3200,4700,3700,3500,5000,5000,3800,4000,3200,3600,3700,4100,4300,5000,3600,4500,3200,6000,6000,4000,5000,6000,4500,5100,4500,5000,4500,3500,3500,4000,5000,5500,3500,3500,4500,4400,5000,5000,4200,6000,5500,4500,4000,8000,3500,3200],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8 ...

# %%
cheap=data[data['Average Cost for two']<800].sort_values(by='Average Cost for two').drop_duplicates().tail(60)

# %% [markdown]
# New Delhi also has many cheap restraunts also

# %%
figg=px.pie(cheap,values='Average Cost for two',names='City')
figg.show()
# Out:
# <div>                            <div id="37c20d39-c46c-4872-a6c7-1c5c667ead76" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37c20d39-c46c-4872-a6c7-1c5c667ead76")) {                    Plotly.newPlot(                        "37c20d39-c46c-4872-a6c7-1c5c667ead76",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"City=%{label}\u003cbr\u003eAverage Cost for two=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["New Delhi","Guwahati","New Delhi","Gurgaon","Jaipur","New Delhi","New Delhi","Noida","New Delhi","Jaipur","New Delhi","Gurgaon","New Delhi","New Delhi","Noida","Noida","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","Gurgaon","New Delhi","New Delhi","New Delhi","New Delhi","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","Mangalore","New Delhi","New Delhi","Noida","Faridabad","New Delhi","New Delhi","Nagpur","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","Noida","New Delhi","New Delhi","Noida","New Delhi","New Delhi","Dehradun","Gurgaon"],"legendgroup":"","name":"","showlegend":true,"values":[750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750,750],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d85 ...

# %%
top_rated=data[data['Aggregate rating']>4.5]

# %%
low_rated=data[data['Aggregate rating']<3.4]

# %% [markdown]
# Top Rated restraunts city wise

# %%
figure=px.bar(top_rated,x='City',y='Aggregate rating')
figure.show()
# Out:
# <div>                            <div id="54d0e367-a500-4b15-ba5e-8292736753b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54d0e367-a500-4b15-ba5e-8292736753b0")) {                    Plotly.newPlot(                        "54d0e367-a500-4b15-ba5e-8292736753b0",                        [{"alignmentgroup":"True","hovertemplate":"City=%{x}\u003cbr\u003eAggregate rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Agra","Ahmedabad","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bhopal","Bhubaneshwar","Chennai","Chennai","Chennai","Chennai","Chennai","Coimbatore","Coimbatore","Dehradun","Goa","Goa","Goa","Goa","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Guwahati","Guwahati","Guwahati","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Hyderabad","Jaipur","Jaipur","Kochi","Kolkata","Kolkata","Kolkata","Kolkata","Kolkata","Lucknow","Lucknow","Lucknow","Ludhiana","Mumbai","Mumbai","Mumbai","Nagpur","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","Pune","Secunderabad","Vadodara","Vizag","Vizag"],"xaxis":"x","y":[4.9,4.6,4.7,4.8,4.6,4.7,4.7,4.6,4.6,4.9,4.6,4.8,4.6,4.6,4.9,4.6,4.6,4.9,4.9,4.8,4.6,4.6,4.7,4.6,4.6,4.6,4.9,4.6,4.6,4.7,4.8,4.8,4.6,4.7,4.9,4.9,4.7,4.6,4.9,4.8,4.7,4.7,4.9,4.6,4.6,4.8,4.6,4.9,4.9,4.9,4.6,4.7,4.6,4.7,4.6,4.9,4.9,4.7,4.9,4.7,4.6,4.9,4.6,4.9,4.6,4.6,4.6,4.8,4.7,4.6,4.7,4.7,4.6,4.6,4.8,4.6,4.6,4.6,4.9],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666 ...

# %% [markdown]
# Low Rated restraunts city wise

# %%
figure=px.scatter(low_rated,x='City',y='Aggregate rating',color='Rating color')
figure.show()
# Out:
# <div>                            <div id="022e7912-f369-4f6e-bbba-7cc57611c608" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("022e7912-f369-4f6e-bbba-7cc57611c608")) {                    Plotly.newPlot(                        "022e7912-f369-4f6e-bbba-7cc57611c608",                        [{"hovertemplate":"Rating color=Orange\u003cbr\u003eCity=%{x}\u003cbr\u003eAggregate rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Orange","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Orange","showlegend":true,"x":["Allahabad","Allahabad","Allahabad","Allahabad","Allahabad","Allahabad","Allahabad","Aurangabad","Aurangabad","Aurangabad","Aurangabad","Aurangabad","Aurangabad","Aurangabad","Aurangabad","Aurangabad","Aurangabad","Bhopal","Chandigarh","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Faridabad","Ghaziabad","Ghaziabad","Ghaziabad","Ghaziabad","Ghaziabad","Ghaziabad","Ghaziabad","Ghaziabad","Ghaziabad","Ghaziabad","Ghaziabad","Ghaziabad","Ghaziabad","Ghaziabad","Ghaziabad","Ghaziabad","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gurgaon","Gur ...

# %% [markdown]
# City wise analysis how many City has Online delivery System

# %%
data.groupby('City').agg('Has Online delivery').value_counts().sort_values(ascending=False).unstack().fillna(0).astype(int).sort_values(['No','Yes'],ascending=False)
# Out:
# Has Online delivery    No   Yes
# City
# New Delhi            3984  1489
# Noida                 716   364
# Gurgaon               693   425
# Faridabad             216    35
# Amritsar               21     0
# Bhubaneshwar           21     0
# Guwahati               21     0
# Lucknow                21     0
# Agra                   20     0
# Allahabad              20     0
# Aurangabad             20     0
# Bhopal                 20     0
# Dehradun               20     0
# Goa                    20     0
# Indore                 20     0
# Kanpur                 20     0
# Ludhiana               20     0
# Mangalore              20     0
# Mysore                 20     0
# Nashik                 20     0
# Patna                  20     0
# Puducherry             20     0
# Ranchi                 20     0
# Surat                  20     0
# Vadodara               20     0
# Varanasi               20     0
# Vizag                  20     0
# Ghaziabad              15    10
# Kochi                  15     5
# Bangalore              13     7
# Coimbatore             13     7
# Mumbai                 13     7
# Pune                   13     7
# Kolkata                12     8
# Chandigarh             12     6
# Hyderabad              11     7
# Ahmedabad              10    11
# Jaipur                 10    10
# Nagpur                 10    10
# Chennai                 7    13
# Secunderabad            1     1
# Panchkula               1     0
# Mohali                  0     1

# %% [markdown]
# City wise analysis How many city has table booking feature

# %%
a=data.groupby('City').agg('Has Table booking').value_counts().sort_values(ascending=False)

a.unstack().fillna(0).astype(int).sort_values(['No','Yes'],ascending=False).reset_index()
# Out:
# Has Table booking          City    No  Yes
# 0                     New Delhi  4758  715
# 1                         Noida   968  112
# 2                       Gurgaon   914  204
# 3                     Faridabad   236   15
# 4                     Ghaziabad    22    3
# 5                     Ahmedabad    21    0
# 6                      Amritsar    21    0
# 7                  Bhubaneshwar    21    0
# 8                      Guwahati    21    0
# 9                       Lucknow    21    0
# 10                         Agra    20    0
# 11                    Allahabad    20    0
# 12                   Aurangabad    20    0
# 13                       Bhopal    20    0
# 14                   Coimbatore    20    0
# 15                     Dehradun    20    0
# 16                          Goa    20    0
# 17                       Indore    20    0
# 18                       Jaipur    20    0
# 19                       Kanpur    20    0
# 20                        Kochi    20    0
# 21                     Ludhiana    20    0
# 22                    Mangalore    20    0
# 23                       Mysore    20    0
# 24                       Nagpur    20    0
# 25                       Nashik    20    0
# 26                        Patna    20    0
# 27                   Puducherry    20    0
# 28                       Ranchi    20    0
# 29                        Surat    20    0
# 30                     Vadodara    20    0
# 31                     Varanasi    20    0
# 32                        Vizag    20    0
# 33                   Chandigarh    18    0
# 34                    Bangalore    14    6
# 35                      Kolkata    11    9
# 36                       Mumbai    11    9
# 37                    Hyderabad     8   10
# 38                      Chennai     7   13
# 39                         Pune     7   13
# 40                       Mohali     1    0
# 41                    Panchkula     1    0
# 42                 Secunderabad     0    2

# %% [markdown]
# top rated restraunt city wise on map

# %%
top_rated=data[data['Aggregate rating']>4.5]
fig = px.scatter_mapbox(top_rated, lat="Latitude", lon="Longitude", hover_name="City", hover_data=["Aggregate rating", "Restaurant Name"],
                        color_discrete_sequence=["fuchsia"], zoom=4, height=300)
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(title='Highly rated Resturants Location',
                  autosize=True,
                  hovermode='closest',
                  showlegend=False)
fig.update_layout(
    autosize=False,
    width=800,
    height=500,)

fig.show()
# Out:
# <div>                            <div id="728d8f8c-127f-494b-a37c-47764a34c7fd" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById
New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","New Delhi","Pune","Secunderabad","Vadodara","Vizag","Vizag"],"lat":[27.16185,23.02874796,12.97022064,12.9791658,12.90622878,12.934179,12.93329764,12.94993396,13.0291977,23.214294,0.0,13.058616,13.08187778,13.066762,12.981615,12.98604688,11.01629845,11.02611735,30.36128079,15.58565833,0.0,15.15794444,15.496162,28.4946295,28.4950691,28.4803156,28.4872636,28.460271,28.441123,28.4679257,28.4682268,28.4691662,26.16149,26.1802428,26.172119,17.41233045,17.42281912,17.43380875,17.4382631,17.43166813,17.440827,26.9051 ...

# %%
data.head(2)
# Out:
#      Restaurant ID      Restaurant Name  Country Code  City  \
# 624        3400025           Jahanpanah             1  Agra
# 625        3400341  Rangrezz Restaurant             1  Agra
#
#                                                Address    Locality  \
# 624  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...  Agra Cantt
# 625  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...  Agra Cantt
#
#      Locality Verbose  Longitude   Latitude               Cuisines  \
# 624  Agra Cantt, Agra  78.011544  27.161661  North Indian, Mughlai
# 625  Agra Cantt, Agra   0.000000   0.000000  North Indian, Mughlai
#
#      Average Cost for two            Currency Has Table booking  \
# 624                   850  Indian Rupees(Rs.)                No
# 625                   700  Indian Rupees(Rs.)                No
#
#     Has Online delivery Is delivering now Switch to order menu  Price range  \
# 624                  No                No                   No            3
# 625                  No                No                   No            2
#
#      Aggregate rating Rating color Rating text  Votes Country
# 624               3.9       Yellow        Good    140   India
# 625               3.5       Yellow        Good     71   India

# %%
delhi=data[(data['Cuisines']=='North Indian') & (data['City']=='New Delhi')]

# %% [markdown]
# map of new delhi where north indian cuisines is eaten the most (zoom in to see the places in delhi)

# %%
delhi=data[(data['Cuisines']=='North Indian') & (data['City']=='New Delhi')]
fig = px.scatter_mapbox(delhi, lat="Latitude", lon="Longitude", hover_name="City", hover_data=["Cuisines", "Restaurant Name"],
                        color_discrete_sequence=["fuchsia"], zoom=6, height=500)
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(title='North Indian Cuisines in delhi',
                  autosize=True,
                  hovermode='closest',
                  showlegend=False)
fig.update_layout(
    autosize=False,
    width=800,
    height=500,)

fig.show()
# Out:
# <div>                            <div id="0b24ad63-b7d5-45c3-a588-700f7a762f7e" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b24ad63-b7d5-45c3-a588-700f7a762f7e")) {                    Plotly.newPlot(                        "0b24ad63-b7d5-45c3-a588-700f7a762f7e",                        [{"customdata":[["North Indian","PM 2 AM Food Bank"],["North Indian","Punjabi Chaap Corner"],["North Indian","Lemon Chick"],["North Indian","Tandoori Kebab"],["North Indian","The Mirch Masala"],["North Indian","Puran Dhaba"],["North Indian","Rama Desi Ghee Meat Wala"],["North Indian","Pandit Ji Paranthe Wale"],["North Indian","Apni Rasoi"],["North Indian","Balaji Dhaba"],["North Indian","High Street Kitchen & Bar"],["North Indian","Punjabi Tadka"],["North Indian","Break Fast Point"],["North Indian","Breakfast Corner"],["North Indian","Vaishno Punj